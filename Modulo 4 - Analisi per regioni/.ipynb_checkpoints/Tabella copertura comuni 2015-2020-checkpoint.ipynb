# %%
import pandas as pd
df = pd.read_csv('csv/copertura_regionale.csv')
df
# Out:
#      Regione/Ripartizione  percentuale comuni  percentuale popolazione
# 0                Piemonte                94.2                     96.0
# 1           Valle d'Aosta                91.9                     91.2
# 2               Lombardia                97.5                     98.9
# 3     Trentino-Alto Adige                92.2                     93.5
# 4                  Veneto                91.1                     92.9
# 5   Friuli-Venezia Giulia                94.9                     94.7
# 6                 Liguria                94.0                     97.5
# 7          Emilia-Romagna                93.9                     97.3
# 8                 Toscana                90.1                     96.6
# 9                  Umbria                94.6                     95.4
# 10                 Marche                90.8                     93.2
# 11                  Lazio                87.3                     93.4
# ...
