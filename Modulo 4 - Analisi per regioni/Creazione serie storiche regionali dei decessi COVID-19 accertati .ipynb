# %% [markdown]
# <h2>CREAZIONE SERIE STORICHE DEI DECESSI COVID ACCERATI SU BASE REGIONALE IN BASE ALLA PERCENTUALE DELLA COPERTURA COMUNALE DEI DECESSI TOTALE

# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
df = pd.read_csv('csv/decessi_covid19_regioni.csv')
df.head()
# Out:
#                   data stato  codice_regione denominazione_regione        lat  \
# 0  2020-02-24T18:00:00   ITA              13               Abruzzo  42.351222
# 1  2020-02-24T18:00:00   ITA              17            Basilicata  40.639471
# 2  2020-02-24T18:00:00   ITA              18              Calabria  38.905976
# 3  2020-02-24T18:00:00   ITA              15              Campania  40.839566
# 4  2020-02-24T18:00:00   ITA               8        Emilia-Romagna  44.494367
#
#         long  ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 0  13.398438                       0                  0                     0
# 1  15.805148                       0                  0                     0
# 2  16.594402                       0                  0                     0
# 3  14.250850                       0                  0                     0
# 4  11.341721                      10                  2                    12
#
#    isolamento_domiciliare  ...  variazione_totale_positivi  nuovi_positivi  \
# 0                       0  ...                           0               0
# 1                       0  ...                           0               0
# 2                       0  ...                           0               0
# 3                       0  ...                           0               0
# 4                       6  ...                           0              18
#
#    dimessi_guariti  deceduti  casi_da_sospetto_diagnostico  casi_da_screening  \
# 0                0         0                           NaN                NaN
# 1                0         0                           NaN                NaN
# 2                0         0                           NaN                NaN
# 3                0         0                           NaN                NaN
# 4                0         0                           NaN                NaN
#
#    totale_casi  tamponi  casi_testati  note
# 0            0        5           NaN   NaN
# 1            0        0           NaN   NaN
# 2            0        1           NaN   NaN
# 3            0       10           NaN   NaN
# 4           18      148           NaN   NaN
#
# [5 rows x 21 columns]

# %%
df.drop(['stato', 'codice_regione', 'lat', 'long', 'ricoverati_con_sintomi','terapia_intensiva', 'totale_ospedalizzati',
        'isolamento_domiciliare', 'variazione_totale_positivi', 'nuovi_positivi', 'dimessi_guariti', 
         'casi_da_sospetto_diagnostico', 'casi_da_screening','totale_casi','tamponi', 'casi_testati', 'note', 
         'totale_positivi'], axis=1, inplace=True)
df.head()
# Out:
#                   data denominazione_regione  deceduti
# 0  2020-02-24T18:00:00               Abruzzo         0
# 1  2020-02-24T18:00:00            Basilicata         0
# 2  2020-02-24T18:00:00              Calabria         0
# 3  2020-02-24T18:00:00              Campania         0
# 4  2020-02-24T18:00:00        Emilia-Romagna         0

# %%
df['data'] = pd.to_datetime(df['data'], format='%Y-%m-%d')
df['data'] = df['data'].dt.strftime('%Y-%m-%d')
df.head()
# Out:
#          data denominazione_regione  deceduti
# 0  2020-02-24               Abruzzo         0
# 1  2020-02-24            Basilicata         0
# 2  2020-02-24              Calabria         0
# 3  2020-02-24              Campania         0
# 4  2020-02-24        Emilia-Romagna         0

# %%
df['data'] = pd.to_datetime(df['data'], format='%Y-%m-%d')
df['deceduti'] = pd.to_numeric(df['deceduti'])

# %% [markdown]
# Estrapolazione dei decessi COVID-19 accertati relativi ai mesi di <b>marzo</b>, <b>aprile</b>, <b>maggio</b>, <b>giugno</b>, <b>luglio</b>, <b>agosto</b> e <b>settembre</b>

# %%
df = df[df['data'] > '2020-02-29']
df = df[df['data'] < '2020-10-01']
df
# Out:
#            data denominazione_regione  deceduti
# 126  2020-03-01               Abruzzo         0
# 127  2020-03-01            Basilicata         0
# 128  2020-03-01              Calabria         0
# 129  2020-03-01              Campania         0
# 130  2020-03-01        Emilia-Romagna         8
# ...         ...                   ...       ...
# 4615 2020-09-30               Sicilia       311
# 4616 2020-09-30               Toscana      1164
# 4617 2020-09-30                Umbria        85
# 4618 2020-09-30         Valle d'Aosta       146
# 4619 2020-09-30                Veneto      2178
#
# [4494 rows x 3 columns]

# %%
#numero di record
index = df.index
record = len(index)
print(record)
# Out:
# 4494

# %%
import numpy as np
deceduti = df['deceduti']
print('mean', np.mean(deceduti))
print('min', np.min(deceduti))
print('max', np.max(deceduti))
# Out:
# mean 1338.0318202047174
# min 0
# max 16955

# %% [markdown]
# Dai dati diffusi dalla Protezione Civile italiana sono stati estratti i decessi sudivisi per ogni regione.
# <br />
# Per ottenere il numero totale di decessi COVID-19 per ogni regione nei mesi di marzo, aprile, maggio e giugno; la colonna `decessi` contenente il valore incrementanto dei decessi è stata sottoposta all'operazione di differenza.
# <br />
# Successivamente i valori giornalieri sono stati raggruppati a livello mensile.
# <br />
# La serie storica ottenuta è stata a sua volta moltiplicata per la percentuale di copertura comunale relativa ai decessi totali ISTAT con cui saranno confrontate le serie storiche regionali dei decessi COVID-19 ottenute.

# %% [markdown]
# <h2>ABRUZZO</h2>

# %%
abruzzo = df[df['denominazione_regione'] =='Abruzzo']
abruzzo.head()
# Out:
#           data denominazione_regione  deceduti
# 126 2020-03-01               Abruzzo         0
# 147 2020-03-02               Abruzzo         0
# 168 2020-03-03               Abruzzo         0
# 189 2020-03-04               Abruzzo         0
# 210 2020-03-05               Abruzzo         0

# %%
abruzzo.drop(['denominazione_regione'], axis=1, inplace=True)
abruzzo.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 126 2020-03-01         0
# 147 2020-03-02         0
# 168 2020-03-03         0
# 189 2020-03-04         0
# 210 2020-03-05         0

# %%
abruzzo=abruzzo.set_index('data')
abruzzo.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
abruzzo = abruzzo.diff()
abruzzo.fillna(0, inplace=True)
abruzzo.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
abruzzo = abruzzo.groupby(pd.Grouper(freq='M')).sum()
abruzzo
# Out:
#             deceduti
# data
# 2020-03-31     115.0
# 2020-04-30     205.0
# 2020-05-31      85.0
# 2020-06-30      59.0
# 2020-07-31       8.0
# 2020-08-31       0.0
# 2020-09-30       9.0

# %%
abruzzo.to_csv('csv/regioni_covid/abruzzo.csv')

# %% [markdown]
# <h2>BASILICATA</h2>

# %%
basilicata = df[df['denominazione_regione']=='Basilicata']
basilicata.head()
# Out:
#           data denominazione_regione  deceduti
# 127 2020-03-01            Basilicata         0
# 148 2020-03-02            Basilicata         0
# 169 2020-03-03            Basilicata         0
# 190 2020-03-04            Basilicata         0
# 211 2020-03-05            Basilicata         0

# %%
basilicata.drop(['denominazione_regione'], axis=1, inplace=True)
basilicata.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 127 2020-03-01         0
# 148 2020-03-02         0
# 169 2020-03-03         0
# 190 2020-03-04         0
# 211 2020-03-05         0

# %%
basilicata = basilicata.set_index('data')
basilicata.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
basilicata = basilicata.diff()
basilicata.fillna(0, inplace=True)
basilicata.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
basilicata = basilicata.groupby(pd.Grouper(freq='M')).sum()
basilicata
# Out:
#             deceduti
# data
# 2020-03-31       7.0
# 2020-04-30      18.0
# 2020-05-31       2.0
# 2020-06-30       0.0
# 2020-07-31       1.0
# 2020-08-31       0.0
# 2020-09-30       1.0

# %%
basilicata.to_csv('csv/regioni_covid/basilicata.csv')

# %% [markdown]
# <h2>CALABRIA</h2>

# %%
calabria = df[df['denominazione_regione']=='Calabria']
calabria.head()
# Out:
#           data denominazione_regione  deceduti
# 128 2020-03-01              Calabria         0
# 149 2020-03-02              Calabria         0
# 170 2020-03-03              Calabria         0
# 191 2020-03-04              Calabria         0
# 212 2020-03-05              Calabria         0

# %%
calabria.drop(['denominazione_regione'], axis=1, inplace=True)
calabria.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 128 2020-03-01         0
# 149 2020-03-02         0
# 170 2020-03-03         0
# 191 2020-03-04         0
# 212 2020-03-05         0

# %%
calabria = calabria.set_index('data')
calabria.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
calabria = calabria.diff()
calabria.fillna(0, inplace=True)
calabria.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
calabria = calabria.groupby(pd.Grouper(freq='M')).sum()
calabria
# Out:
#             deceduti
# data
# 2020-03-31      36.0
# 2020-04-30      50.0
# 2020-05-31      11.0
# 2020-06-30       0.0
# 2020-07-31       0.0
# 2020-08-31       0.0
# 2020-09-30       3.0

# %%
calabria.to_csv('csv/regioni_covid/calabria.csv')

# %% [markdown]
# <h2>CAMPANIA</h2>

# %%
campania = df[df['denominazione_regione']=='Campania']
campania.head()
# Out:
#           data denominazione_regione  deceduti
# 129 2020-03-01              Campania         0
# 150 2020-03-02              Campania         0
# 171 2020-03-03              Campania         0
# 192 2020-03-04              Campania         0
# 213 2020-03-05              Campania         0

# %%
campania.drop(['denominazione_regione'], axis=1, inplace=True)
campania.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 129 2020-03-01         0
# 150 2020-03-02         0
# 171 2020-03-03         0
# 192 2020-03-04         0
# 213 2020-03-05         0

# %%
campania = campania.set_index('data')
campania.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
campania = campania.diff()
campania.fillna(0, inplace=True)
campania.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
campania = campania.groupby(pd.Grouper(freq='M')).sum()
campania.head()
# Out:
#             deceduti
# data
# 2020-03-31     133.0
# 2020-04-30     226.0
# 2020-05-31      53.0
# 2020-06-30      20.0
# 2020-07-31       3.0

# %%
campania.to_csv('csv/regioni_covid/campania.csv')

# %% [markdown]
# <h2>EMILIA ROMAGNA</h2>

# %%
emilia_romagna = df[df['denominazione_regione']=='Emilia-Romagna']
emilia_romagna.head()
# Out:
#           data denominazione_regione  deceduti
# 130 2020-03-01        Emilia-Romagna         8
# 151 2020-03-02        Emilia-Romagna        11
# 172 2020-03-03        Emilia-Romagna        18
# 193 2020-03-04        Emilia-Romagna        22
# 214 2020-03-05        Emilia-Romagna        30

# %%
emilia_romagna.drop(['denominazione_regione'], axis=1, inplace=True)
emilia_romagna.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 130 2020-03-01         8
# 151 2020-03-02        11
# 172 2020-03-03        18
# 193 2020-03-04        22
# 214 2020-03-05        30

# %%
emilia_romagna = emilia_romagna.set_index('data')
emilia_romagna
# Out:
#             deceduti
# data
# 2020-03-01         8
# 2020-03-02        11
# 2020-03-03        18
# 2020-03-04        22
# 2020-03-05        30
# ...              ...
# 2020-09-26      4481
# 2020-09-27      4482
# 2020-09-28      4482
# 2020-09-29      4484
# 2020-09-30      4484
#
# [214 rows x 1 columns]

# %%
emilia_romagna = emilia_romagna.diff()
emilia_romagna.fillna(8, inplace=True)
emilia_romagna.head()
# Out:
#             deceduti
# data
# 2020-03-01       8.0
# 2020-03-02       3.0
# 2020-03-03       7.0
# 2020-03-04       4.0
# 2020-03-05       8.0

# %%
emilia_romagna = emilia_romagna.groupby(pd.Grouper(freq='M')).sum()
emilia_romagna
# Out:
#             deceduti
# data
# 2020-03-31    1644.0
# 2020-04-30    1907.0
# 2020-05-31     563.0
# 2020-06-30     146.0
# 2020-07-31      29.0
# 2020-08-31     174.0
# 2020-09-30      21.0

# %%
emilia_romagna.to_csv('csv/regioni_covid/emilia_romagna.csv')

# %% [markdown]
# <h2>LOMBARDIA</h2>

# %%
lombardia = df[df['denominazione_regione']=='Lombardia']
lombardia.head()
# Out:
#           data denominazione_regione  deceduti
# 134 2020-03-01             Lombardia        24
# 155 2020-03-02             Lombardia        38
# 176 2020-03-03             Lombardia        55
# 197 2020-03-04             Lombardia        73
# 218 2020-03-05             Lombardia        98

# %%
lombardia.drop(['denominazione_regione'], axis=1, inplace=True)
lombardia.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 134 2020-03-01        24
# 155 2020-03-02        38
# 176 2020-03-03        55
# 197 2020-03-04        73
# 218 2020-03-05        98

# %%
lombardia = lombardia.set_index('data')
lombardia.head()
# Out:
#             deceduti
# data
# 2020-03-01        24
# 2020-03-02        38
# 2020-03-03        55
# 2020-03-04        73
# 2020-03-05        98

# %%
lombardia = lombardia.diff()
lombardia.fillna(24, inplace=True)
lombardia.head()
# Out:
#             deceduti
# data
# 2020-03-01      24.0
# 2020-03-02      14.0
# 2020-03-03      17.0
# 2020-03-04      18.0
# 2020-03-05      25.0

# %%
lombardia = lombardia.groupby(pd.Grouper(freq='M')).sum()
lombardia.head()
# Out:
#             deceduti
# data
# 2020-03-31    7199.0
# 2020-04-30    6573.0
# 2020-05-31    2340.0
# 2020-06-30     532.0
# 2020-07-31     162.0

# %%
lombardia.to_csv('csv/regioni_covid/lombardia.csv')

# %% [markdown]
# <h2>FRIULI VENEZIA GIULIA </h2>

# %%
friuli_venezia_giulia = df[df['denominazione_regione']=='Friuli Venezia Giulia']
friuli_venezia_giulia.head()
# Out:
#           data  denominazione_regione  deceduti
# 131 2020-03-01  Friuli Venezia Giulia         0
# 152 2020-03-02  Friuli Venezia Giulia         0
# 173 2020-03-03  Friuli Venezia Giulia         0
# 194 2020-03-04  Friuli Venezia Giulia         0
# 215 2020-03-05  Friuli Venezia Giulia         0

# %%
friuli_venezia_giulia.drop(['denominazione_regione'], axis=1, inplace=True)
friuli_venezia_giulia.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 131 2020-03-01         0
# 152 2020-03-02         0
# 173 2020-03-03         0
# 194 2020-03-04         0
# 215 2020-03-05         0

# %%
friuli_venezia_giulia = friuli_venezia_giulia.set_index('data')
friuli_venezia_giulia.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
friuli_venezia_giulia = friuli_venezia_giulia.diff()
friuli_venezia_giulia.fillna(0, inplace=True)
friuli_venezia_giulia.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
friuli_venezia_giulia = friuli_venezia_giulia.groupby(pd.Grouper(freq='M')).sum()
friuli_venezia_giulia.head()
# Out:
#             deceduti
# data
# 2020-03-31     113.0
# 2020-04-30     176.0
# 2020-05-31      44.0
# 2020-06-30      12.0
# 2020-07-31       0.0

# %%
friuli_venezia_giulia.to_csv('csv/regioni_covid/friuli_venezia_giulia.csv')

# %% [markdown]
# <h2>LAZIO</h2>

# %%
lazio = df[df['denominazione_regione']=='Lazio']
lazio.head()
# Out:
#           data denominazione_regione  deceduti
# 132 2020-03-01                 Lazio         0
# 153 2020-03-02                 Lazio         0
# 174 2020-03-03                 Lazio         0
# 195 2020-03-04                 Lazio         0
# 216 2020-03-05                 Lazio         0

# %%
lazio.drop(['denominazione_regione'], axis=1, inplace=True)
lazio.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 132 2020-03-01         0
# 153 2020-03-02         0
# 174 2020-03-03         0
# 195 2020-03-04         0
# 216 2020-03-05         0

# %%
lazio = lazio.set_index('data')
lazio.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
lazio = lazio.diff()
lazio.fillna(0, inplace=True)
lazio.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
lazio = lazio.groupby(pd.Grouper(freq='M')).sum()
lazio.head()
# Out:
#             deceduti
# data
# 2020-03-31     162.0
# 2020-04-30     279.0
# 2020-05-31     294.0
# 2020-06-30     102.0
# 2020-07-31      26.0

# %%
lazio.to_csv('csv/regioni_covid/lazio.csv')

# %% [markdown]
# <h2>LIGURIA</h2>

# %%
liguria = df[df['denominazione_regione']=='Liguria']
liguria.head()
# Out:
#           data denominazione_regione  deceduti
# 133 2020-03-01               Liguria         0
# 154 2020-03-02               Liguria         0
# 175 2020-03-03               Liguria         1
# 196 2020-03-04               Liguria         1
# 217 2020-03-05               Liguria         3

# %%
liguria.drop(['denominazione_regione'], axis=1, inplace=True)
liguria.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 133 2020-03-01         0
# 154 2020-03-02         0
# 175 2020-03-03         1
# 196 2020-03-04         1
# 217 2020-03-05         3

# %%
liguria = liguria.set_index('data')
liguria.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         1
# 2020-03-04         1
# 2020-03-05         3

# %%
liguria = liguria.diff()
liguria.fillna(0, inplace=True)
liguria.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       1.0
# 2020-03-04       0.0
# 2020-03-05       2.0

# %%
liguria = liguria.groupby(pd.Grouper(freq='M')).sum()
liguria.head()
# Out:
#             deceduti
# data
# 2020-03-31     428.0
# 2020-04-30     739.0
# 2020-05-31     298.0
# 2020-06-30      93.0
# 2020-07-31       9.0

# %%
liguria.to_csv('csv/regioni_covid/liguria.csv')

# %% [markdown]
# <h2>MARCHE</h2>

# %%
marche = df[df['denominazione_regione']=='Marche']
marche.head()
# Out:
#           data denominazione_regione  deceduti
# 135 2020-03-01                Marche         0
# 156 2020-03-02                Marche         1
# 177 2020-03-03                Marche         2
# 198 2020-03-04                Marche         4
# 219 2020-03-05                Marche         4

# %%
marche.drop(['denominazione_regione'], axis=1, inplace=True)
marche.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 135 2020-03-01         0
# 156 2020-03-02         1
# 177 2020-03-03         2
# 198 2020-03-04         4
# 219 2020-03-05         4

# %%
marche = marche.set_index('data')
marche.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         1
# 2020-03-03         2
# 2020-03-04         4
# 2020-03-05         4

# %%
marche = marche.diff()
marche.fillna(0, inplace=True)
marche.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       1.0
# 2020-03-03       1.0
# 2020-03-04       2.0
# 2020-03-05       0.0

# %%
marche = marche.groupby(pd.Grouper(freq='M')).sum()
marche.head()
# Out:
#             deceduti
# data
# 2020-03-31     452.0
# 2020-04-30     454.0
# 2020-05-31      81.0
# 2020-06-30       4.0
# 2020-07-31      -4.0

# %%
marche.to_csv('csv/regioni_covid/marche.csv')

# %% [markdown]
# <h2>MOLISE</h2>

# %%
molise = df[df['denominazione_regione']=='Molise']
molise.head()
# Out:
#           data denominazione_regione  deceduti
# 136 2020-03-01                Molise         0
# 157 2020-03-02                Molise         0
# 178 2020-03-03                Molise         0
# 199 2020-03-04                Molise         0
# 220 2020-03-05                Molise         0

# %%
molise.drop(['denominazione_regione'], axis=1, inplace=True)
molise.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 136 2020-03-01         0
# 157 2020-03-02         0
# 178 2020-03-03         0
# 199 2020-03-04         0
# 220 2020-03-05         0

# %%
molise = molise.set_index('data')
molise.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
molise = molise.diff()
molise.fillna(0, inplace=True)
molise.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
molise = molise.groupby(pd.Grouper(freq='M')).sum()
molise.head()
# Out:
#             deceduti
# data
# 2020-03-31       9.0
# 2020-04-30      12.0
# 2020-05-31       1.0
# 2020-06-30       1.0
# 2020-07-31       0.0

# %%
molise.to_csv('csv/regioni_covid/molise.csv')

# %% [markdown]
# <h2>TOSCANA</h2>

# %%
toscana = df[df['denominazione_regione']=='Toscana']
toscana.head()
# Out:
#           data denominazione_regione  deceduti
# 143 2020-03-01               Toscana         0
# 164 2020-03-02               Toscana         0
# 185 2020-03-03               Toscana         0
# 206 2020-03-04               Toscana         0
# 227 2020-03-05               Toscana         0

# %%
toscana.drop(['denominazione_regione'], axis=1, inplace=True)
toscana.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 143 2020-03-01         0
# 164 2020-03-02         0
# 185 2020-03-03         0
# 206 2020-03-04         0
# 227 2020-03-05         0

# %%
toscana = toscana.set_index('data')
toscana.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
toscana = toscana.diff()
toscana.fillna(0, inplace=True)
toscana.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
toscana = toscana.groupby(pd.Grouper(freq='M')).sum()
toscana.head()
# Out:
#             deceduti
# data
# 2020-03-31     244.0
# 2020-04-30     598.0
# 2020-05-31     199.0
# 2020-06-30      63.0
# 2020-07-31      30.0

# %%
toscana.to_csv('csv/regioni_covid/toscana.csv')

# %% [markdown]
# <h2>PIEMONTE</h2>

# %%
piemonte = df[df['denominazione_regione']=='Piemonte']
piemonte.head()
# Out:
#           data denominazione_regione  deceduti
# 139 2020-03-01              Piemonte         0
# 160 2020-03-02              Piemonte         0
# 181 2020-03-03              Piemonte         0
# 202 2020-03-04              Piemonte         0
# 223 2020-03-05              Piemonte         2

# %%
piemonte.drop(['denominazione_regione'], axis=1, inplace=True)
piemonte.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 139 2020-03-01         0
# 160 2020-03-02         0
# 181 2020-03-03         0
# 202 2020-03-04         0
# 223 2020-03-05         2

# %%
piemonte = piemonte.set_index('data')
piemonte.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         2

# %%
piemonte = piemonte.diff()
piemonte.fillna(0, inplace=True)
piemonte.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       2.0

# %%
piemonte = piemonte.groupby(pd.Grouper(freq='M')).sum()
piemonte.head()
# Out:
#             deceduti
# data
# 2020-03-31     854.0
# 2020-04-30    2212.0
# 2020-05-31     801.0
# 2020-06-30     223.0
# 2020-07-31      39.0

# %%
piemonte.to_csv('csv/regioni_covid/piemonte.csv')

# %% [markdown]
# <h2>TRENTINO ALTO ADIGE </h2>

# %% [markdown]
# Comprende la provicia autonoma di Trento e di Bolzano.

# %%
trento = df[df['denominazione_regione'] == 'P.A. Trento']
bolzano = df[df['denominazione_regione']=='P.A. Bolzano']
trentino = pd.merge(trento, bolzano, how='outer')
trentino.head()
# Out:
#         data denominazione_regione  deceduti
# 0 2020-03-01           P.A. Trento         0
# 1 2020-03-02           P.A. Trento         0
# 2 2020-03-03           P.A. Trento         0
# 3 2020-03-04           P.A. Trento         0
# 4 2020-03-05           P.A. Trento         0

# %%
trentino.drop(['denominazione_regione'], axis=1, inplace=True)
trentino.head()
# Out:
#         data  deceduti
# 0 2020-03-01         0
# 1 2020-03-02         0
# 2 2020-03-03         0
# 3 2020-03-04         0
# 4 2020-03-05         0

# %%
trentino = trentino.groupby('data').sum()
trentino.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
trentino = trentino.diff()
trentino.fillna(0, inplace=True)
trentino.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
trentino = trentino.groupby(pd.Grouper(freq='M')).sum()
trentino.head()
# Out:
#             deceduti
# data
# 2020-03-31     240.0
# 2020-04-30     453.0
# 2020-05-31      60.0
# 2020-06-30     -56.0
# 2020-07-31       0.0

# %%
trentino.to_csv('csv/regioni_covid/trentino.csv')

# %% [markdown]
# <h2>PUGLIA</h2>

# %%
puglia = df[df['denominazione_regione']=='Puglia']
puglia.head()
# Out:
#           data denominazione_regione  deceduti
# 140 2020-03-01                Puglia         0
# 161 2020-03-02                Puglia         0
# 182 2020-03-03                Puglia         0
# 203 2020-03-04                Puglia         1
# 224 2020-03-05                Puglia         1

# %%
puglia.drop(['denominazione_regione'], axis=1, inplace=True)
puglia.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 140 2020-03-01         0
# 161 2020-03-02         0
# 182 2020-03-03         0
# 203 2020-03-04         1
# 224 2020-03-05         1

# %%
puglia = puglia.set_index('data')
puglia.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         1
# 2020-03-05         1

# %%
puglia = puglia.diff()
puglia.fillna(0, inplace=True)
puglia.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       1.0
# 2020-03-05       0.0

# %%
puglia = puglia.groupby(pd.Grouper(freq='M')).sum()
puglia.head()
# Out:
#             deceduti
# data
# 2020-03-31     110.0
# 2020-04-30     305.0
# 2020-05-31      89.0
# 2020-06-30      41.0
# 2020-07-31       7.0

# %%
puglia.to_csv('csv/regioni_covid/puglia.csv')

# %% [markdown]
# <h2>SARDEGNA</h2>

# %%
sardegna = df[df['denominazione_regione']=='Sardegna']
sardegna.head()
# Out:
#           data denominazione_regione  deceduti
# 141 2020-03-01              Sardegna         0
# 162 2020-03-02              Sardegna         0
# 183 2020-03-03              Sardegna         0
# 204 2020-03-04              Sardegna         0
# 225 2020-03-05              Sardegna         0

# %%
sardegna.drop(['denominazione_regione'], axis=1, inplace=True)
sardegna.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 141 2020-03-01         0
# 162 2020-03-02         0
# 183 2020-03-03         0
# 204 2020-03-04         0
# 225 2020-03-05         0

# %%
sardegna = sardegna.set_index('data')
sardegna.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
sardegna = sardegna.diff()
sardegna.fillna(0, inplace=True)
sardegna.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
sardegna = sardegna.groupby(pd.Grouper(freq='M')).sum()
sardegna.head()
# Out:
#             deceduti
# data
# 2020-03-31      31.0
# 2020-04-30      85.0
# 2020-05-31      14.0
# 2020-06-30       3.0
# 2020-07-31       1.0

# %%
sardegna.to_csv('csv/regioni_covid/sardegna.csv')

# %% [markdown]
# <h2>SICILIA</h2>

# %%
sicilia = df[df['denominazione_regione']=='Sicilia']
sicilia.head()
# Out:
#           data denominazione_regione  deceduti
# 142 2020-03-01               Sicilia         0
# 163 2020-03-02               Sicilia         0
# 184 2020-03-03               Sicilia         0
# 205 2020-03-04               Sicilia         0
# 226 2020-03-05               Sicilia         0

# %%
sicilia.drop(['denominazione_regione'], axis=1, inplace=True)
sicilia.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 142 2020-03-01         0
# 163 2020-03-02         0
# 184 2020-03-03         0
# 205 2020-03-04         0
# 226 2020-03-05         0

# %%
sicilia = sicilia.set_index('data')
sicilia.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
sicilia = sicilia.diff()
sicilia.fillna(0, inplace=True)
sicilia.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
sicilia = sicilia.groupby(pd.Grouper(freq='M')).sum()
sicilia.head()
# Out:
#             deceduti
# data
# 2020-03-31      81.0
# 2020-04-30     154.0
# 2020-05-31      39.0
# 2020-06-30       8.0
# 2020-07-31       1.0

# %%
sicilia.to_csv('csv/regioni_covid/sicilia.csv')

# %% [markdown]
# <h2>UMBRIA</h2>

# %%
umbria = df[df['denominazione_regione']=='Umbria']
umbria.head()
# Out:
#           data denominazione_regione  deceduti
# 144 2020-03-01                Umbria         0
# 165 2020-03-02                Umbria         0
# 186 2020-03-03                Umbria         0
# 207 2020-03-04                Umbria         0
# 228 2020-03-05                Umbria         0

# %%
umbria.drop(['denominazione_regione'], axis=1, inplace=True)
umbria.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 144 2020-03-01         0
# 165 2020-03-02         0
# 186 2020-03-03         0
# 207 2020-03-04         0
# 228 2020-03-05         0

# %%
umbria = umbria.set_index('data')
umbria.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
umbria = umbria.diff()
umbria.fillna(0, inplace=True)
umbria.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
umbria = umbria.groupby(pd.Grouper(freq='M')).sum()
umbria.head()
# Out:
#             deceduti
# data
# 2020-03-31      37.0
# 2020-04-30      30.0
# 2020-05-31       9.0
# 2020-06-30       4.0
# 2020-07-31       0.0

# %%
umbria.to_csv('csv/regioni_covid/umbria.csv')

# %% [markdown]
# <h2>VALLE D'AOSTA</h2>

# %%
valle_aosta = df[df['denominazione_regione']=="Valle d'Aosta"]
valle_aosta.head()
# Out:
#           data denominazione_regione  deceduti
# 145 2020-03-01         Valle d'Aosta         0
# 166 2020-03-02         Valle d'Aosta         0
# 187 2020-03-03         Valle d'Aosta         0
# 208 2020-03-04         Valle d'Aosta         0
# 229 2020-03-05         Valle d'Aosta         0

# %%
valle_aosta.drop(['denominazione_regione'], axis=1, inplace=True)
valle_aosta.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 145 2020-03-01         0
# 166 2020-03-02         0
# 187 2020-03-03         0
# 208 2020-03-04         0
# 229 2020-03-05         0

# %%
valle_aosta = valle_aosta.set_index('data')
valle_aosta.head()
# Out:
#             deceduti
# data
# 2020-03-01         0
# 2020-03-02         0
# 2020-03-03         0
# 2020-03-04         0
# 2020-03-05         0

# %%
valle_aosta = valle_aosta.diff()
valle_aosta.fillna(0, inplace=True)
valle_aosta.head()
# Out:
#             deceduti
# data
# 2020-03-01       0.0
# 2020-03-02       0.0
# 2020-03-03       0.0
# 2020-03-04       0.0
# 2020-03-05       0.0

# %%
valle_aosta = valle_aosta.groupby(pd.Grouper(freq='M')).sum()
valle_aosta.head()
# Out:
#             deceduti
# data
# 2020-03-31      56.0
# 2020-04-30      81.0
# 2020-05-31       6.0
# 2020-06-30       3.0
# 2020-07-31       0.0

# %%
valle_aosta.to_csv('csv/regioni_covid/valle_aosta.csv')

# %% [markdown]
# <h2>VENETO</h2>

# %%
veneto = df[df['denominazione_regione']=="Veneto"]
veneto.head()
# Out:
#           data denominazione_regione  deceduti
# 146 2020-03-01                Veneto         2
# 167 2020-03-02                Veneto         2
# 188 2020-03-03                Veneto         3
# 209 2020-03-04                Veneto         6
# 230 2020-03-05                Veneto        10

# %%
veneto.drop(['denominazione_regione'], axis=1, inplace=True)
veneto.head()
# Out:
# c:\users\monta\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           data  deceduti
# 146 2020-03-01         2
# 167 2020-03-02         2
# 188 2020-03-03         3
# 209 2020-03-04         6
# 230 2020-03-05        10

# %%
veneto = veneto.set_index('data')
veneto.head()
# Out:
#             deceduti
# data
# 2020-03-01         2
# 2020-03-02         2
# 2020-03-03         3
# 2020-03-04         6
# 2020-03-05        10

# %%
veneto = veneto.diff()
veneto.fillna(2, inplace=True)
veneto.head()
# Out:
#             deceduti
# data
# 2020-03-01       2.0
# 2020-03-02       0.0
# 2020-03-03       1.0
# 2020-03-04       3.0
# 2020-03-05       4.0

# %%
veneto = veneto.groupby(pd.Grouper(freq='M')).sum()
veneto.head()
# Out:
#             deceduti
# data
# 2020-03-31     477.0
# 2020-04-30     982.0
# 2020-05-31     459.0
# 2020-06-30      94.0
# 2020-07-31      62.0

# %%
veneto.to_csv('csv/regioni_covid/veneto.csv')
